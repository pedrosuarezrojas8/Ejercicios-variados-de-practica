# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\LEON SUAREZ\Desktop\VSC\Visualizacion datos\Proyectos de estudio\diamonds.csv", sep = ',')

# %%
print(df.shape)
df.head(4)
# Out:
# (53940, 10)
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63

# %%
df.carat.sum()
# Out:
# np.float64(43040.87)

# %%
df.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
df.price.describe()
# Out:
# count    53940.000000
# mean      3932.799722
# std       3989.439738
# min        326.000000
# 25%        950.000000
# 50%       2401.000000
# 75%       5324.250000
# max      18823.000000
# Name: price, dtype: float64

# %%
df.value_counts
# Out:
# <bound method DataFrame.value_counts of        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# ...

# %%
df_premium = df[(df.carat > 2)&(df.cut == 'Premium')]
df_premium
# Out:
#        carat      cut color clarity  depth  table  price     x     y     z
# 12246   2.06  Premium     J      I1   61.2   58.0   5203  8.10  8.07  4.95
# 15319   2.08  Premium     H      I1   61.7   57.0   6150  8.23  8.18  5.06
# 15905   2.15  Premium     H      I1   62.9   57.0   6357  8.25  8.20  5.18
# 15941   2.03  Premium     G      I1   61.1   58.0   6377  8.11  8.06  4.94
# 16341   2.21  Premium     H      I1   62.2   58.0   6535  8.31  8.27  5.16
# ...      ...      ...   ...     ...    ...    ...    ...   ...   ...   ...
# 27731   2.55  Premium     I     VS1   61.8   62.0  18766  8.70  8.65  5.36
# 27737   2.05  Premium     F     SI2   60.2   59.0  18784  8.28  8.33  5.00
# 27742   2.04  Premium     H     SI1   58.1   60.0  18795  8.37  8.28  4.84
# 27744   2.29  Premium     I     SI1   61.8   59.0  18797  8.52  8.45  5.24
# 27749   2.29  Premium     I     VS2   60.8   60.0  18823  8.50  8.47  5.16
#
# [743 rows x 10 columns]

# %%
df_premium.groupby('price').sum()
# Out:
#        carat      cut color clarity  depth  table     x     y     z
# price
# 5203    2.06  Premium     J      I1   61.2   58.0  8.10  8.07  4.95
# 6150    2.08  Premium     H      I1   61.7   57.0  8.23  8.18  5.06
# 6357    2.15  Premium     H      I1   62.9   57.0  8.25  8.20  5.18
# 6377    2.03  Premium     G      I1   61.1   58.0  8.11  8.06  4.94
# 6535    2.21  Premium     H      I1   62.2   58.0  8.31  8.27  5.16
# ...      ...      ...   ...     ...    ...    ...   ...   ...   ...
# 18766   2.55  Premium     I     VS1   61.8   62.0  8.70  8.65  5.36
# 18784   2.05  Premium     F     SI2   60.2   59.0  8.28  8.33  5.00
# 18795   2.04  Premium     H     SI1   58.1   60.0  8.37  8.28  4.84
# 18797   2.29  Premium     I     SI1   61.8   59.0  8.52  8.45  5.24
# 18823   2.29  Premium     I     VS2   60.8   60.0  8.50  8.47  5.16
#
# [651 rows x 9 columns]

# %%
df.agrupado = df.groupby('price')
df.agrupado

# %%
df.agrupado.groups
# Out:
# {326: [0, 1], 327: [2], 334: [3], 335: [4], 336: [5, 6], 337: [7, 8], 338: [9], 339: [10], 340: [11], 342: [12], 344: [13], 345: [14, 15], 348: [16], 351: [17, 18, 19, 20], 352: [21], 353: [22, 23, 24], 354: [25], 355: [26], 357: [27, 28, 29, 28260, 28261, 28262, 28263, 28264], 358: [28265], 360: [28266, 28267], 361: [28268, 28269, 28270, 28271], 362: [28272, 28273, 28274, 28275], 363: [28276, 28277, 28278, 28279, 28280], 364: [28281, 28282, 28283], 365: [28284], 366: [28285], 367: [28286, 28287, 28288, 28289, 31590, 31591, 31592, 31593, 31594, 31595, 31596, 31597, 31598, 31599, 31600, 31601, 31602], 368: [31603, 31604, 31605, 31606, 31607, 31608], 369: [31609, 31610, 31611], 370: [31612], 371: [31613, 31614, 31615], 372: [31616], 373: [31617, 31618, 31619, 34920, 34921, 34922, 34923, 34924, 34925, 34926, 34927], 374: [34928, 34929, 34930, 34931, 34932], 375: [34933, 34934], 376: [34935, 34936], 377: [34937, 34938, 34939], 378: [34940, 34941, 34942, 34943, 34944, 34945, 34946, 34947]
# ...

# %%
df.agrupado.max()
# Out:
#        carat        cut color clarity  depth  table     x     y     z
# price
# 326     0.23    Premium     E     SI2   61.5   61.0  3.95  3.98  2.43
# 327     0.23       Good     E     VS1   56.9   65.0  4.05  4.07  2.31
# 334     0.29    Premium     I     VS2   62.4   58.0  4.20  4.23  2.63
# 335     0.31       Good     J     SI2   63.3   58.0  4.34  4.35  2.75
# 336     0.24  Very Good     J    VVS2   62.8   57.0  3.95  3.98  2.48
# ...      ...        ...   ...     ...    ...    ...   ...   ...   ...
# 18803   2.00  Very Good     H     SI1   62.8   57.0  7.95  8.00  5.01
# 18804   2.07      Ideal     G     SI2   62.5   55.0  8.20  8.13  5.11
# 18806   1.51      Ideal     G      IF   61.7   55.0  7.37  7.41  4.56
# 18818   2.00  Very Good     G     SI1   63.5   56.0  7.90  7.97  5.04
# 18823   2.29    Premium     I     VS2   60.8   60.0  8.50  8.47  5.16
#
# [11602 rows x 9 columns]
