# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder, OneHotEncoder

# %%
# Creamos un generador de números aleatorios utilizando la función default_rng() de NumPy.
rng = np.random.default_rng()

#Usamos para generar números enteros aleatorios entre 0 y 100, con un tamaño de 10.
a_values = rng.integers(low = 0, high = 100, size = 10) 

#Usamos para generar números enteros aleatorios entre 100 y 500, con un tamaño de 10.
b_values = rng.integers(low = 100, high = 500, size = 10)

#Creamos un DataFrame de pandas con dos columnas, 'A' y 'B', utilizando los valores generados anteriormente.
data = pd.DataFrame({'A': a_values, 'B': b_values})
data
# Out:
#     A    B
# 0  66  387
# 1  43  312
# 2  86  234
# 3  77  484
# 4  54  139
# 5  79  449
# 6  40  149
# 7   2  435
# 8  28  339
# 9  76  290

# %%
#describe es un método de pandas que se utiliza para obtener estadísticas descriptivas de un DataFrame o una Serie. 
# En este caso, se está aplicando al DataFrame 'data' para obtener estadísticas descriptivas de la columna 'A'. 
# Esto incluirá información como el conteo, la media, la desviación estándar, los valores mínimos y máximos, y los percentiles.
data.A.describe()
# Out:
# count    10.000000
# mean     55.100000
# std      26.855374
# min       2.000000
# 25%      40.750000
# 50%      60.000000
# 75%      76.750000
# max      86.000000
# Name: A, dtype: float64

# %%
data.B.describe()
# Out:
# count     10.000000
# mean     321.800000
# std      121.079221
# min      139.000000
# 25%      248.000000
# 50%      325.500000
# 75%      423.000000
# max      484.000000
# Name: B, dtype: float64
